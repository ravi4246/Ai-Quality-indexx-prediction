# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('air quality.csv')
df.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.info
# Out:
# <bound method DataFrame.info of                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df.dropna(subset=['AQI'],inplace = True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Xylene        15372
# PM10           7086
# NH3            6536
# Toluene        5826
# Benzene        3535
# NOx            1857
# O3              807
# PM2.5           678
# SO2             605
# CO              445
# NO2             391
# NO              387
# Date              0
# City              0
# AQI               0
# AQI_Bucket        0
# dtype: int64

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (24850, 16)

# %%
df.describe().T
# Out:
#            count        mean         std    min      25%      50%       75%  \
# PM2.5    24172.0   67.476613   63.075398   0.04  29.0000   48.785   80.9250
# PM10     17764.0  118.454435   89.487976   0.03  56.7775   96.180  150.1825
# NO       24463.0   17.622421   22.421138   0.03   5.6600    9.910   20.0300
# NO2      24459.0   28.978391   24.627054   0.01  11.9400   22.100   38.2400
# NOx      22993.0   32.289012   30.712855   0.00  13.1100   23.680   40.1700
# NH3      18314.0   23.848366   25.875981   0.01   8.9600   16.310   30.3600
# CO       24405.0    2.345267    7.075208   0.00   0.5900    0.930    1.4800
# SO2      24245.0   14.362933   17.428693   0.01   5.7300    9.220   15.1400
# O3       24043.0   34.912885   21.724525   0.01  19.2500   31.250   46.0800
# Benzene  21315.0    3.458668   16.036020   0.00   0.2300    1.290    3.3400
# Toluene  19024.0    9.525714   20.881085   0.00   1.0275    3.575   10.1800
# Xylene    9478.0    3.588683    6.754324   0.00   0.3900    1.420    4.1200
# AQI      24850.0  166.463581  140.696585  13.00  81.0000  118.000  208.0000
#
#              max
# PM2.5     914.94
# PM10      917.08
# NO        390.68
# NO2       362.21
# NOx       378.24
# NH3       352.89
# CO        175.81
# SO2       186.08
# O3        257.73
# Benzene   455.03
# Toluene   454.85
# Xylene    170.37
# AQI      2049.00

# %%
null_values_percentage = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
null_values_percentage
# Out:
# Xylene        61.859155
# PM10          28.515091
# NH3           26.301811
# Toluene       23.444668
# Benzene       14.225352
# NOx            7.472837
# O3             3.247485
# PM2.5          2.728370
# SO2            2.434608
# CO             1.790744
# NO2            1.573441
# NO             1.557344
# Date           0.000000
# City           0.000000
# AQI            0.000000
# AQI_Bucket     0.000000
# dtype: float64

# %% [markdown]
# #### key consideration:
# -xylene has the highest percentage of missing values = 61.85%
# -PM10 and NH3 28-26%

# %% [markdown]
# ## week 2 visualization

# %%
df['Xylene'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['PM10'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['NH3'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['Toluene'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['Benzene'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['Nox'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nox'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df['Nox'].plot(kind = 'hist', figsize=(10,5))
#       2 plt.legend()
#       3 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Nox'

# %%
df['NOx'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['O3'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['PM2.5'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['SO2'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['CO'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
df['AQI'].plot(kind = 'hist', figsize=(10,5))
plt.legend()
plt.show()

# %%
sns.displot(df, x='AQI', color='blue')
plt.show()

# %%
sns.set_theme(style="darkgrid")
graph = sns.catplot(x="City", kind='count', data=df, height=5, aspect=3)
graph.set_xticklabels(rotation=90)

# %%
sns.set_theme(style="darkgrid")
graph = sns.catplot(x="City", kind='count', data=df,col="AQI_Bucket", col_wrap=2, height=3.5, aspect=3)
graph.set_xticklabels(rotation=90)

# %%
graph1 = sns.catplot(x='City', y='PM2.5', kind='box', data=df, height=5, aspect=3)
graph1.set_xticklabels(rotation=90)

# %%
graph2 = sns.catplot(x='City', y='NO2', kind='box', data=df, height=5, aspect=3)
graph2.set_xticklabels(rotation=90)

# %%
graph4 = sns.catplot(x='City', y='O3', kind='box', data=df, height=5, aspect=3)
graph4.set_xticklabels(rotation=90)

# %%
graph3 = sns.catplot(x='City', y='SO2', kind='box', data=df, height=5, aspect=3)
graph3.set_xticklabels(rotation=90)

# %%
graph5 = sns.catplot(x='AQI_Bucket', kind='count', data=df, height=6, aspect=3)
graph5.set_xticklabels(rotation=90)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Xylene        15372
# PM10           7086
# NH3            6536
# Toluene        5826
# Benzene        3535
# NOx            1857
# O3              807
# PM2.5           678
# SO2             605
# CO              445
# NO2             391
# NO              387
# Date              0
# City              0
# AQI               0
# AQI_Bucket        0
# dtype: int64

# %%
df.describe().loc['mean']
# Out:
# PM2.5       67.476613
# PM10       118.454435
# NO          17.622421
# NO2         28.978391
# NOx         32.289012
# NH3         23.848366
# CO           2.345267
# SO2         14.362933
# O3          34.912885
# Benzene      3.458668
# Toluene      9.525714
# Xylene       3.588683
# AQI        166.463581
# Name: mean, dtype: float64

# %%
df=df.replace({
   "PM2.5":{np.nan:67.476613},
   "PM10":{np.nan: 118.454435},
    "NO":{np.nan: 17.622421},
    "NO2":{np.nan: 28.978391},
    "NOx":{np.nan: 32.289012},
    "NH3":{np.nan:  23.848366},
    "CO":{np.nan: 2.345267},
    "SO2":{np.nan: 14.362933},
    "O3":{np.nan: 34.912885},
    "Benzene":{np.nan: 3.458668},
    "Toluene":{np.nan: 9.525714},
    "Xylene":{np.nan: 3.588683},
})

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
df = df.drop(['AQI_Bucket'], axis=1)

# %%
df.head()
# Out:
#          City        Date   PM2.5        PM10     NO    NO2    NOx        NH3  \
# 28  Ahmedabad  2015-01-29   83.13  118.454435   6.93  28.71  33.72  23.848366
# 29  Ahmedabad  2015-01-30   79.84  118.454435  13.85  28.68  41.08  23.848366
# 30  Ahmedabad  2015-01-31   94.52  118.454435  24.39  32.66  52.61  23.848366
# 31  Ahmedabad  2015-02-01  135.99  118.454435  43.48  42.08  84.57  23.848366
# 32  Ahmedabad  2015-02-02  178.33  118.454435  54.56  35.31  72.80  23.848366
#
#        CO    SO2      O3  Benzene  Toluene  Xylene    AQI
# 28   6.93  49.52   59.76     0.02     0.00    3.14  209.0
# 29  13.85  48.49   97.07     0.04     0.00    4.81  328.0
# 30  24.39  67.39  111.33     0.24     0.01    7.67  514.0
# 31  43.48  75.23  102.70     0.40     0.04   25.87  782.0
# 32  54.56  55.04  107.38     0.46     0.06   35.61  914.0

# %%
sns.boxplot(data=df[['PM2.5', 'PM10']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['NO', 'NO2', 'NOx', 'NH3']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['O3', 'SO2']])
# Out:
# <Axes: >

# %%
def replace_outliers(df):
    for column in df.select_dtypes(include=['number']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3-Q1
        lb = Q1 - 1.5 * IQR
        ub = Q3 + 1.5 * IQR
        df[column] = df[column].apply(
            lambda x: Q1 if x < lb else (Q3 if x > ub else x)
        )
    return df

# %%
df = replace_outliers(df)

# %%
df.describe().T
# Out:
#            count        mean        std    min    25%         50%         75%  \
# PM2.5    24850.0   55.174281  31.829575   0.04  29.56   50.165000   79.505625
# PM10     24850.0  101.351323  39.079916   0.03  71.78  118.454435  122.955625
# NO       24850.0   12.507694   8.762015   0.03   5.72   10.075000   19.710000
# NO2      24850.0   25.901114  16.669494   0.01  12.09   22.535000   37.910000
# NOx      24850.0   26.574513  16.138682   0.00  14.03   25.720000   38.170000
# NH3      24850.0   19.486584   9.630370   0.01  11.28   23.848366   24.710000
# CO       24850.0    1.040507   0.615436   0.00   0.59    0.950000    1.530000
# SO2      24850.0   10.334743   5.680901   0.01   5.79    9.430000   14.890000
# O3       24850.0   33.177781  17.487724   0.01  19.64   32.060000   45.395625
# Benzene  24850.0    2.098520   1.828135   0.00   0.34    1.810000    3.458668
# Toluene  24850.0    6.222709   4.696068   0.00   1.58    6.790000    9.525714
# Xylene   24850.0    3.304507   0.558607   1.25   2.65    3.588683    3.588683
# AQI      24850.0  146.932032  87.421731  13.00  81.00  118.000000  208.000000
#
#             max
# PM2.5    154.30
# PM10     199.70
# NO        40.68
# NO2       76.62
# NOx       74.38
# NH3       44.85
# CO         2.94
# SO2       28.52
# O3        83.99
# Benzene    8.13
# Toluene   21.44
# Xylene     4.99
# AQI      398.00

# %%
sns.boxplot(data=df[['PM2.5', 'PM10']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['O3', 'SO2']])
# Out:
# <Axes: >

# %%
sns.displot(df, x='AQI', color='blue')
plt.show()

# %%
df1 = df.drop(columns=['City'])

# %%
df_numeric = df1.select_dtypes(include=['float64'])
print(df_numeric.head())  # This will display only numeric columns
plt.figure(figsize=(12, 8))
sns.heatmap(df_numeric.corr(), annot=True, cmap='Pastel1')
plt.show()
# Out:
#        PM2.5        PM10     NO    NO2    NOx        NH3    CO    SO2  \
# 28   83.1300  118.454435   6.93  28.71  33.72  23.848366  1.53  14.89
# 29   79.8400  118.454435  13.85  28.68  41.08  23.848366  1.53  14.89
# 30   94.5200  118.454435  24.39  32.66  52.61  23.848366  1.53  14.89
# 31  135.9900  118.454435  19.71  42.08  38.17  23.848366  1.53  14.89
# 32   79.5075  118.454435  19.71  35.31  72.80  23.848366  1.53  14.89
#
#          O3  Benzene  Toluene    Xylene    AQI
# 28  59.7600     0.02     0.00  3.140000  209.0
# 29  45.3975     0.04     0.00  4.810000  328.0
# 30  45.3975     0.24     0.01  3.588683  208.0
# 31  45.3975     0.40     0.04  3.588683  208.0
# 32  45.3975     0.46     0.06  3.588683  208.0

# %%
print(df1.dtypes)
# Out:
# Date        object
# PM2.5      float64
# PM10       float64
# NO         float64
# NO2        float64
# NOx        float64
# NH3        float64
# CO         float64
# SO2        float64
# O3         float64
# Benzene    float64
# Toluene    float64
# Xylene     float64
# AQI        float64
# dtype: object

# %%
df_numeric = df1.drop(columns=['Date'])  # Drop the Date column

# %% [markdown]
# ## week 3 data modeling

# %%
df.drop(['Date','City'], axis = 1, inplace=True)
df.head()
# Out:
#        PM2.5        PM10     NO    NO2    NOx        NH3    CO    SO2  \
# 28   83.1300  118.454435   6.93  28.71  33.72  23.848366  1.53  14.89
# 29   79.8400  118.454435  13.85  28.68  41.08  23.848366  1.53  14.89
# 30   94.5200  118.454435  24.39  32.66  52.61  23.848366  1.53  14.89
# 31  135.9900  118.454435  19.71  42.08  38.17  23.848366  1.53  14.89
# 32   79.5075  118.454435  19.71  35.31  72.80  23.848366  1.53  14.89
#
#          O3  Benzene  Toluene    Xylene    AQI
# 28  59.7600     0.02     0.00  3.140000  209.0
# 29  45.3975     0.04     0.00  4.810000  328.0
# 30  45.3975     0.24     0.01  3.588683  208.0
# 31  45.3975     0.40     0.04  3.588683  208.0
# 32  45.3975     0.46     0.06  3.588683  208.0

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Sample DataFrame (Replace this with your actual DataFrame)
# df = pd.read_csv("your_file.csv")  # Load your dataset

# Drop the categorical column 'AQI_Bucket'
df_numeric = df.drop(columns=['AQI_Bucket'])

# Handle missing values (choose one):
df_numeric = df_numeric.fillna(df_numeric.mean())  # Fill NaNs with column mean
# df_numeric = df_numeric.dropna()  # Alternative: Drop rows with NaNs

# Apply StandardScaler
scaler = StandardScaler()
df1 = scaler.fit_transform(df_numeric)

# Print the transformed NumPy array
print(df1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 8
#       2 import pandas as pd
#       4 # Sample DataFrame (Replace this with your actual DataFrame)
#       5 # df = pd.read_csv("your_file.csv")  # Load your dataset
#       6
#       7 # Drop the categorical column 'AQI_Bucket'
# ----> 8 df_numeric = df.drop(columns=['AQI_Bucket'])
#      10 # Handle missing values (choose one):
#      11 df_numeric = df_numeric.fillna(df_numeric.mean())  # Fill NaNs with column mean
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['AQI_Bucket'] not found in axis"

# %%
print(df.dtypes)

# %%
df_numeric = df.drop(columns=['AQI_Bucket'])  # Keep only numeric columns
df_scaled = StandardScaler().fit_transform(df_numeric)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df_numeric = df.drop(columns=['AQI_Bucket'])  # Keep only numeric columns
#       2 df_scaled = StandardScaler().fit_transform(df_numeric)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['AQI_Bucket'] not found in axis"

# %%
df_scaled = StandardScaler().fit_transform(df_numeric)
df
# Out:
#           PM2.5        PM10     NO    NO2    NOx        NH3    CO    SO2  \
# 28      83.1300  118.454435   6.93  28.71  33.72  23.848366  1.53  14.89
# 29      79.8400  118.454435  13.85  28.68  41.08  23.848366  1.53  14.89
# 30      94.5200  118.454435  24.39  32.66  52.61  23.848366  1.53  14.89
# 31     135.9900  118.454435  19.71  42.08  38.17  23.848366  1.53  14.89
# 32      79.5075  118.454435  19.71  35.31  72.80  23.848366  1.53  14.89
# ...         ...         ...    ...    ...    ...        ...   ...    ...
# 29526   15.0200   50.940000   7.68  25.06  19.54  12.470000  0.47   8.55
# 29527   24.3800   74.090000   3.42  26.06  16.53  11.990000  0.52  12.72
# 29528   22.9100   65.730000   3.45  29.53  18.33  10.710000  0.48   8.42
# 29529   16.6400   49.970000   4.05  29.26  18.80  10.030000  0.52   9.84
# 29530   15.0000   66.000000   0.40  26.85  14.05   5.200000  0.59   2.10
#
#             O3   Benzene    Toluene    Xylene    AQI
# 28     59.7600  0.020000   0.000000  3.140000  209.0
# 29     45.3975  0.040000   0.000000  4.810000  328.0
# 30     45.3975  0.240000   0.010000  3.588683  208.0
# 31     45.3975  0.400000   0.040000  3.588683  208.0
# 32     45.3975  0.460000   0.060000  3.588683  208.0
# ...        ...       ...        ...       ...    ...
# 29526  23.3000  2.240000  12.070000  2.650000   41.0
# 29527  30.1400  0.740000   2.210000  2.650000   70.0
# 29528  30.9600  0.010000   0.010000  2.650000   68.0
# 29529  28.3000  0.000000   0.000000  2.650000   54.0
# 29530  17.0500  3.458668   9.525714  3.588683   50.0
#
# [24850 rows x 13 columns]

# %%
df_numeric = df.drop(columns=['AQI_Bucket'])  # Remove categorical column
df_numeric = df_numeric.fillna(df_numeric.mean())  # Fill NaNs with column mean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df_numeric = df.drop(columns=['AQI_Bucket'])  # Remove categorical column
#       2 df_numeric = df_numeric.fillna(df_numeric.mean())  # Fill NaNs with column mean
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['AQI_Bucket'] not found in axis"

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_numeric)  # Now it returns a NumPy array
print(df_scaled)  # This will now show in the format you want
# Out:
# [[ 0.87831149  0.43765334 -0.63658947 ... -1.32511601 -0.29450027
#    0.70999757]
#  [ 0.77494642  0.43765334  0.15319907 ... -1.32511601  2.69513707
#    2.07124258]
#  [ 1.23616198  0.43765334  1.35614288 ... -1.32298652  0.50873294
#    0.69855854]
#  ...
#  [-1.01367767 -0.91151782 -1.03376636 ... -1.32298652 -1.17169925
#   -0.90290618]
#  [-1.21066824 -1.31480214 -0.96528759 ... -1.32511601 -1.17169925
#   -1.06305265]
#  [-1.26219369 -0.90460877 -1.3818668  ...  0.70336955  0.50873294
#   -1.10880878]]

# %%
df_scaled = pd.DataFrame(df1, columns=df_numeric.columns)  # Use df_numeric's columns
print(df_scaled.head())  # Verify output
# Out:
#        PM2.5        PM10     NO    NO2    NOx        NH3    CO    SO2  \
# 28   83.1300  118.454435   6.93  28.71  33.72  23.848366  1.53  14.89
# 29   79.8400  118.454435  13.85  28.68  41.08  23.848366  1.53  14.89
# 30   94.5200  118.454435  24.39  32.66  52.61  23.848366  1.53  14.89
# 31  135.9900  118.454435  19.71  42.08  38.17  23.848366  1.53  14.89
# 32   79.5075  118.454435  19.71  35.31  72.80  23.848366  1.53  14.89
#
#          O3  Benzene  Toluene    Xylene    AQI
# 28  59.7600     0.02     0.00  3.140000  209.0
# 29  45.3975     0.04     0.00  4.810000  328.0
# 30  45.3975     0.24     0.01  3.588683  208.0
# 31  45.3975     0.40     0.04  3.588683  208.0
# 32  45.3975     0.46     0.06  3.588683  208.0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene']]
Y = df['AQI']

# %%
X.head()
# Out:
#        PM2.5        PM10     NO    NO2    NOx        NH3    CO    SO2  \
# 28   83.1300  118.454435   6.93  28.71  33.72  23.848366  1.53  14.89
# 29   79.8400  118.454435  13.85  28.68  41.08  23.848366  1.53  14.89
# 30   94.5200  118.454435  24.39  32.66  52.61  23.848366  1.53  14.89
# 31  135.9900  118.454435  19.71  42.08  38.17  23.848366  1.53  14.89
# 32   79.5075  118.454435  19.71  35.31  72.80  23.848366  1.53  14.89
#
#          O3  Benzene  Toluene    Xylene
# 28  59.7600     0.02     0.00  3.140000
# 29  45.3975     0.04     0.00  4.810000
# 30  45.3975     0.24     0.01  3.588683
# 31  45.3975     0.40     0.04  3.588683
# 32  45.3975     0.46     0.06  3.588683

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print('shape of X train', X_train.shape)
print('shape of X train', X_test.shape)
print('shape of X train', Y_train.shape)
print('shape of X train', Y_test.shape)
# Out:
# shape of X train (19880, 12)
# shape of X train (4970, 12)
# shape of X train (19880,)
# shape of X train (4970,)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")
X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)

LR = LinearRegression()
LR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
import pandas as pd
print(X_train.isnull().sum())  # For DataFrame
print(X_train.isna().sum())    # Alternative way
# Out:
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# dtype: int64
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# dtype: int64

# %%
train_pred = LR.predict(X_train)
test_pred = LR.predict(X_test)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")
X_test = pd.DataFrame(imputer.fit_transform(X_test), columns=X_test.columns)

# %%
RMSE_train = (np.sqrt(mean_squared_error(Y_train, train_pred)))
RMSE_test = (np.sqrt(mean_squared_error(Y_test, test_pred)))
print('RMSE Training data = ', str(RMSE_train))
print('RMSE test data =', str(RMSE_test))
print('_'*60)
print('R Square value for train =', LR.score(X_train,Y_train))
print('R Squared value on test = ', LR.score(X_test,Y_test))
# Out:
# RMSE Training data =  51.73162460795584
# RMSE test data = 50.88099317130839
# ____________________________________________________________
# R Square value for train = 0.6510774205877974
# R Squared value on test =  0.6562598886507953

# %%
knn = KNeighborsRegressor()
knn.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor()

# %%
train_pred = knn.predict(X_train)
test_pred = knn.predict(X_test)
RMSE_train = (np.sqrt(mean_squared_error(Y_train, train_pred)))
RMSE_test = (np.sqrt(mean_squared_error(Y_test, test_pred)))
print('RMSE Training data = ', str(RMSE_train))
print('RMSE test data =', str(RMSE_test))
print('_'*60)
print('R Square value for train =', knn.score(X_train,Y_train))
print('R Squared value on test = ', knn.score(X_test,Y_test))
# Out:
# RMSE Training data =  35.45490921614595
# RMSE test data = 43.536087115032814
# ____________________________________________________________
# R Square value for train = 0.8361035318957133
# R Squared value on test =  0.7483378860374803

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
train_pred = dtr.predict(X_train)
test_pred = dtr.predict(X_test)
RMSE_train = (np.sqrt(mean_squared_error(Y_train, train_pred)))
RMSE_test = (np.sqrt(mean_squared_error(Y_test, test_pred)))
print('RMSE Training data = ', str(RMSE_train))
print('RMSE test data =', str(RMSE_test))
print('_'*60)
print('R Square value for train =', dtr.score(X_train,Y_train))
print('R Squared value on test = ', dtr.score(X_test,Y_test))
# Out:
# RMSE Training data =  2.2684211563088263
# RMSE test data = 48.21140537554586
# ____________________________________________________________
# R Square value for train = 0.9993290900734868
# R Squared value on test =  0.6913838590431235

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
train_pred = rfr.predict(X_train)
test_pred = rfr.predict(X_test)
RMSE_train = (np.sqrt(mean_squared_error(Y_train, train_pred)))
RMSE_test = (np.sqrt(mean_squared_error(Y_test, test_pred)))
print('RMSE Training data = ', str(RMSE_train))
print('RMSE test data =', str(RMSE_test))
print('_'*60)
print('R Square value for train =', rfr.score(X_train,Y_train))
print('R Squared value on test = ', rfr.score(X_test,Y_test))
# Out:
# RMSE Training data =  13.012805140064572
# RMSE test data = 34.2200156921411
# ____________________________________________________________
# R Square value for train = 0.9779220526943021
# R Squared value on test =  0.8445182349461834
